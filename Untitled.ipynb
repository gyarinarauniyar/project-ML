# %%
# !python .\run_pipeline.py --true_csv .\data\True.csv --fake_csv .\data\Fake_Parsable.csv --output_dir .\artifacts\generated --sbert_model all-MiniLM-L6-v2 --min_fake_type_k 4 --max_fake_type_k 8
# Out:
# Traceback (most recent call last):
#   File "C:\Users\adity\Downloads\fake_news_sbert_clustering_project\fake_news_sbert_clustering_project\run_pipeline.py", line 6, in <module>
#     import pandas as pd
# ModuleNotFoundError: No module named 'pandas'
